# %%
import os, sys
from datetime import datetime
import numpy as np, pandas as pd
from sklearn import cross_validation
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import auc, roc_auc_score

sys.path.append('C:\\Users\\Pawel\\PycharmProjects\\Springleaf Marketing Response\\src')
sys.path.append('C:\\Users\\Pawel\\PycharmProjects\\Springleaf Marketing Response\\src\\model_evaluation')
import utilities

# %%
DATA_DIR = "F:\\Pawel\\Kaggle\\Springleaf Marketing Response\\Data"
FEATURES_DATA_DIR = "F:\\Pawel\\Kaggle\\Springleaf Marketing Response\\Data\\Train_Standard_Norm"
PREDICTIONS_DIR = "F:\\Pawel\\Kaggle\\Springleaf Marketing Response\\Data\\Model Predictions"

RESULTS_DIR = "F:\\Pawel\\Kaggle\\Springleaf Marketing Response\\Data\\Model Results"

# %%
X_train = pd.read_hdf(os.path.join(FEATURES_DATA_DIR, 'train_train_features.hf5'), 'data')
X_validation = pd.read_hdf(os.path.join(FEATURES_DATA_DIR, 'train_validation_features.hf5'), 'data')
Y_train = pd.read_hdf(os.path.join(DATA_DIR, 'train_train_y.hf5'), 'data')
Y_validation = pd.read_hdf(os.path.join(DATA_DIR, 'train_validation_y.hf5'), 'data')

# %%
classifier = KNeighborsClassifier(n_neighbors=500)

classifier.fit(X_train[::10], Y_train.iloc[:, 0][::10])
#rf.fit(np.asarray(X_train, order='C'), Y_train.iloc[:, 0])
print 'Start Predictions'
predictions = classifier.predict_proba(X_validation)[:,1][::10]
print roc_auc_score(Y_validation[::10], predictions)
# Out:
# Start Predictions
# 0.636849688479

# %%
predictions
# Out:
# array([ 0.198,  0.166,  0.392, ...,  0.19 ,  0.364,  0.122])

# %%
pd.crosstab(X_train['VAR_0254'], X_train['VAR_0001']).apply(lambda r: r/r.sum(), axis=1)
# Out:
# VAR_0001       0.0       0.5       1.0
# VAR_0254
# 0.000000  0.238239  0.005179  0.756582
# 0.142857  0.000000  0.000000  1.000000
# 0.151786  0.166667  0.000000  0.833333
# 0.160714  0.160494  0.000000  0.839506
# 0.169643  0.104368  0.005057  0.890575
# 0.178571  0.128645  0.004717  0.866638
# 0.187500  0.149846  0.004119  0.846035
# 0.196429  0.138182  0.003636  0.858182
# 0.205357  0.131468  0.005808  0.862724
# 0.214286  0.142114  0.002889  0.854997
# 0.223214  0.136255  0.003601  0.860144
# 0.232143  0.169690  0.003511  0.826799
# 0.241071  0.188889  0.004094  0.807018
# 0.250000  0.192869  0.004322  0.802809
# 0.258929  0.243135  0.001997  0.754868
# 0.267857  0.263718  0.001276  0.735006
# 0.276786  0.281513  0.004966  0.713522
# 0.285714  0.312029  0.004309  0.683662
# 0.294643  0.335031  0.002183  0.662786
# 0.303571  0.342549  0.003232  0.654219
# 0.312500  0.360461  0.003344  0.636195
# 0.321429  0.366555  0.003359  0.630086
# 0.330357  0.390631  0.003604  0.605766
# 0.339286  0.419948  0.003000  0.577053
# 0.348214  0.421464  0.005330  0.573205
# 0.357143  0.407614  0.002096  0.590290
# 0.366071  0.430978  0.003303  0.565720
# 0.375000  0.455969  0.000978  0.543053
# 0.383929  0.467545  0.003954  0.528501
# 0.392857  0.477696  0.003864  0.518440
# ...            ...       ...       ...
# 0.687500  0.646067  0.000000  0.353933
# 0.696429  0.682927  0.000000  0.317073
# 0.705357  0.664430  0.013423  0.322148
# 0.714286  0.704348  0.008696  0.286957
# 0.723214  0.656250  0.010417  0.333333
# 0.732143  0.750000  0.000000  0.250000
# 0.741071  0.740000  0.020000  0.240000
# 0.750000  0.628205  0.000000  0.371795
# 0.758929  0.702128  0.000000  0.297872
# 0.767857  0.693878  0.020408  0.285714
# 0.776786  0.777778  0.000000  0.222222
# 0.785714  0.878788  0.000000  0.121212
# 0.794643  0.944444  0.000000  0.055556
# 0.803571  0.733333  0.000000  0.266667
# 0.812500  0.750000  0.000000  0.250000
# 0.821429  0.833333  0.000000  0.166667
# 0.830357  0.416667  0.000000  0.583333
# 0.839286  0.428571  0.071429  0.500000
# 0.848214  1.000000  0.000000  0.000000
# 0.857143  0.500000  0.000000  0.500000
# 0.866071  0.500000  0.000000  0.500000
# 0.875000  0.000000  0.000000  1.000000
# 0.892857  0.000000  0.000000  1.000000
# 0.901786  1.000000  0.000000  0.000000
# 0.910714  1.000000  0.000000  0.000000
# 0.919643  0.000000  0.000000  1.000000
# 0.937500  1.000000  0.000000  0.000000
# 0.955357  0.000000  0.000000  1.000000
# 0.964286  1.000000  0.000000  0.000000
# 1.000000  0.000000  0.000000  1.000000
#
# [92 rows x 3 columns]
