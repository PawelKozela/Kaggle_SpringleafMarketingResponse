# %%
# %matplotlib inline

# %%
SUBMISSION_FILE_1 = "predictions_2015_10_14__20_49__Standard_Full.csv"

SUBMISSION_FILE_2 = "One_Hot_Simple_With_One_Hot_With_Dates_Full_Blended_Manual.csv"
#SUBMISSION_FILE_2 = "predictions_2015_10_12__7_20__Standard_With_Dates_One_Hot_Full.csv"

# %%
submission_data_1 = pd.read_csv(os.path.join(SUBMISSIONS_DIR, SUBMISSION_FILE_1), sep=',', index_col=0).sample(frac=0.5, random_state=13)
submission_data_2 = pd.read_csv(os.path.join(SUBMISSIONS_DIR, SUBMISSION_FILE_2), sep=',', index_col=0).sample(frac=0.5, random_state=13)

# %%
chart = sns.jointplot(submission_data_1['target'], submission_data_2['target'], kind='scatter', size=15, space=0, xlim=(0,1), ylim=(0,1), alpha=0.2)
