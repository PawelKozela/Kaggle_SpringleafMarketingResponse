# %%
import os, sys
import numpy as np, pandas as pd

sys.path.append('C:\\Users\\Pawel\\PycharmProjects\\Springleaf Marketing Response\\src')
sys.path.append('C:\\Users\\Pawel\\PycharmProjects\\Springleaf Marketing Response\\src\\feature_engineering')
from feature_utilities import identify_feature

# %matplotlib inline

# %%
DATA_DIR = "F:\\Pawel\\Kaggle\\Springleaf Marketing Response\\Data"

FEATURES_DATA_DIR = "F:\\Pawel\\Kaggle\\Springleaf Marketing Response\\Data\\Train_Standard"
NORM_FEATURES_DATA_DIR = "F:\\Pawel\\Kaggle\\Springleaf Marketing Response\\Data\\Train_Standard_Norm"

# %%
X_validation = pd.read_hdf(os.path.join(FEATURES_DATA_DIR, 'train_validation_features.hf5'), 'data')
X_validation_norm = pd.read_hdf(os.path.join(NORM_FEATURES_DATA_DIR, 'train_validation_features.hf5'), 'data')

Y_validation = pd.read_hdf(os.path.join(DATA_DIR, 'train_validation_y.hf5'), 'data')

# %%
for i in range(0, X_validation.shape[1]):
    feature_type = identify_feature(X_validation.iloc[:, i])
    print X_validation.columns[i], feature_type
# Out:
# VAR_0001 ('Int', 'Score', [], -1, None)
# VAR_0002 ('Int', 'Unknown', [], -1, 'Standard')
# VAR_0003 ('Int', 'Unknown', [], -1, 'Standard')
# VAR_0004 ('Int', 'Unknown', [], -1, 'Standard')
# VAR_0005 ('Int', 'Score', [], -1, None)
# VAR_0006 ('Float', 'Score', [-1.0], -1, None)
# VAR_0007 ('Float', 'Score', [-1.0], -1, None)
# VAR_0008 ('Int', 'Score', [], -1, None)
# VAR_0009 ('Int', 'Score', [], -1, None)
# VAR_0010 ('Int', 'Score', [], -1, None)
# VAR_0011 ('Int', 'Score', [], -1, None)
# VAR_0012 ('Int', 'Score', [], -1, None)
# VAR_0013 ('Float', 'Score', [-1.0], -1, None)
# VAR_0014 ('Float', 'Score', [-1.0], -1, None)
# VAR_0015 ('Float', 'Score', [-1.0], -1, None)
# VAR_0016 ('Float', 'Score', [-1.0], -1, None)
# VAR_0017 ('Float', 'Score', [-1.0], -1, None)
# VAR_0018 ('Float', 'Score', [-1.0], -1, None)
# VAR_0019 ('Float', 'Score', [-1.0], -1, None)
# VAR_0020 ('Float', 'Score', [-1.0], -1, None)
# VAR_0021 ('Float', 'Score', [-1.0], -1, None)
# ...

# %%
X_validation['VAR_1566'].value_counts()
# Out:
# 1     6847
# 2     6031
# 0     5619
# 3     4447
# 4     2885
# 5     1671
# 6      852
# 7      429
# 8      178
# 9       62
# 10      18
# 11       5
# 13       2
# 19       1
# dtype: int64

# %%
pd.pivot_table(pd.concat([X_validation['VAR_1566'], Y_validation['target']], axis=1).reset_index(), index='VAR_1566', columns='target', values='ID', aggfunc='count')
# Out:
# target       0     1
# VAR_1566
# 0         4714   905
# 1         5513  1334
# 2         4620  1411
# 3         3257  1190
# 4         2065   820
# 5         1167   504
# 6          546   306
# 7          281   148
# 8          115    63
# 9           42    20
# 10           6    12
# 11           3     2
# 13         NaN     2
# 19         NaN     1

# %%
are_equal = []
are_constant = []
for i in range(0, X_validation.shape[1] - 1):
    if (X_validation.iloc[:, i] == X_validation.iloc[:, i + 1]).all():
        are_equal.append((i, i+1))
    if X_validation.iloc[:, i].value_counts().shape[0] == 1:
        are_constant.append(i)

are_equal
# Out:
# [(7, 8),
#  (8, 9),
#  (9, 10),
#  (10, 11),
#  (17, 18),
#  (18, 19),
#  (19, 20),
#  (20, 21),
#  (21, 22),
#  (22, 23),
#  (23, 24),
#  (24, 25),
#  (25, 26),
#  (26, 27),
#  (27, 28),
#  (28, 29),
#  (29, 30),
#  (30, 31),
#  (37, 38),
#  (38, 39),
#  (39, 40),
#  (40, 41),
#  (42, 43),
#  (179, 180),
#  (180, 181),
#  (187, 188),
#  (188, 189),
#  (189, 190),
#  (190, 191),
#  (191, 192),
#  (209, 210),
#  (225, 226),
#  (391, 392),
#  (392, 393),
#  (394, 395),
#  (442, 443),
#  (523, 524),
#  (524, 525),
#  (525, 526)]

# %%
X_validation[['VAR_0110', 'VAR_0111']][X_validation['VAR_0110'] != X_validation['VAR_0111']].shape, X_validation.shape
# Out:
# ((590, 2), (29047, 1934))

# %%
X_validation['VAR_0106'].value_counts().shape[0]
# Out:
# 3L

# %%
Y_validation[X_validation['VAR_1104'] != 0]
# Out:
#         target
# ID
# 219568       0
# 189262       0
# 19557        0
# 158360       1
# 124105       1
# 148774       0
# 86705        1
# 164629       0
# 192082       0
# 91644        0
# 195773       0
# 50703        0
# 234104       0
# 42160        0
# 72792        0
# 245028       1
# 231814       0
# 117156       0
# 281774       1
