# %% [markdown]
# #  Notes on features

# %% [raw]
# Date features:
# VAR_0073 => 30.4% (44104) non empty values
# VAR_0075 => 100.0% (145175) non empty values
# VAR_0156 => 4.0% (5870) non empty values
# VAR_0157 => 0.6% (920) non empty values
# VAR_0158 => 1.4% (2089) non empty values
# VAR_0159 => 4.0% (5870) non empty values
# VAR_0166 => 9.8% (14230) non empty values
# VAR_0167 => 1.8% (2567) non empty values
# VAR_0168 => 7.4% (10725) non empty values
# VAR_0169 => 9.8% (14230) non empty values
# VAR_0176 => 12.1% (17532) non empty values
# VAR_0177 => 2.3% (3358) non empty values
# VAR_0178 => 8.3% (12073) non empty values
# VAR_0179 => 12.1% (17532) non empty values
# VAR_0204 => 100.0% (145175) non empty values
# VAR_0217 => 100.0% (145175) non empty values

# %% [raw]
# VAR_0204 -> Spans only 4 days, probably the date of email campaing ?

# %% [raw]
# Most date variables have very strong correlation with the target (or at least looks like)

# %% [raw]
# Correlation coefficient (*100) on non nulls:
# VAR_0073 75
# VAR_0075 -33
# VAR_0156 39
# VAR_0157 53
# VAR_0158 -8
# VAR_0159 20
# VAR_0166 62
# VAR_0167 17
# VAR_0168 1
# VAR_0169 30
# VAR_0176 62
# VAR_0177 17
# VAR_0178 0
# VAR_0179 24
# VAR_0204 nan
# VAR_0217 92

# %% [raw]
# 05/10/2015 Experiments on Dates
#
# Dates Only
# XGBoost, 300 runs => 0.64680
#
# Feature importances
# VAR_0073 6159
# VAR_0075 5124
# VAR_0156 1218
# VAR_0157 139
# VAR_0158 254
# VAR_0159 912
# VAR_0166 2761
# VAR_0167 527
# VAR_0168 2035
# VAR_0169 3036
# VAR_0176 3501
# VAR_0177 1231
# VAR_0178 2386
# VAR_0179 2902
# VAR_0204 765
# VAR_0217 4787
#
# Dates With Mod 7
# XGBoost, 300 runs => 0.64404 (But get the max around run 100, at 0.646)
#
# Feature Importances
# VAR_0073 4258
# VAR_0075 3494
# VAR_0156 880
# VAR_0157 41
# VAR_0158 125
# VAR_0159 532
# VAR_0166 1718
# VAR_0167 240
# VAR_0168 1355
# VAR_0169 1976
# VAR_0176 2405
# VAR_0177 690
# VAR_0178 1382
# VAR_0179 2181
# VAR_0204 602
# VAR_0217 2593
# MOD_0073 2166
# MOD_0075 1595
# MOD_0156 462
# MOD_0157 51
# MOD_0158 129
# MOD_0159 514
# MOD_0166 1190
# MOD_0167 267
# MOD_0168 834
# MOD_0169 1059
# MOD_0176 1308
# MOD_0177 251
# MOD_0178 783
# MOD_0179 1285
# MOD_0204 970
# MOD_0217 1884
#
# Dates With Mod 7, Mod 30
# XGBoost, 300 runs => 0.64364 (But get the max around run 100, at 0.647546)
#
# VAR_0073 3109
# VAR_0075 2685
# VAR_0156 607
# VAR_0157 41
# VAR_0158 98
# VAR_0159 420
# VAR_0166 1330
# VAR_0167 205
# VAR_0168 1005
# VAR_0169 1733
# VAR_0176 1616
# VAR_0177 701
# VAR_0178 1051
# VAR_0179 1938
# VAR_0204 598
# VAR_0217 2780
# MOD_0073 1686
# MOD_0075 1522
# MOD_0156 375
# MOD_0157 39
# MOD_0158 146
# MOD_0159 399
# MOD_0166 904
# MOD_0167 269
# MOD_0168 714
# MOD_0169 879
# MOD_0176 1111
# MOD_0177 445
# MOD_0178 731
# MOD_0179 1001
# MOD_0204 933
# MOD_0217 1705
# MOD_Month_0073 2435
# MOD_Month_0075 2707
# MOD_Month_0156 595
# MOD_Month_0157 48
# MOD_Month_0158 116
# MOD_Month_0159 588
# MOD_Month_0166 1299
# MOD_Month_0167 335
# MOD_Month_0168 893
# MOD_Month_0169 1080
# MOD_Month_0176 1396
# MOD_Month_0177 497
# MOD_Month_0178 1040
# MOD_Month_0179 1344
# MOD_Month_0204 242
# MOD_Month_0217 2764
#
# Dates With Mod 7, Mod 30, Mod 365
# XGBoost, 300 runs => 0.64615 (But get the max around run 100, at 0.647078)
#
# Feature Importances
# VAR_0073 2286
# VAR_0075 2213
# VAR_0156 323
# VAR_0157 15
# VAR_0158 28
# VAR_0159 229
# VAR_0166 937
# VAR_0167 145
# VAR_0168 599
# VAR_0169 1359
# VAR_0176 1157
# VAR_0177 613
# VAR_0178 611
# VAR_0179 1321
# VAR_0204 398
# VAR_0217 1914
# MOD_0073 1459
# MOD_0075 1282
# MOD_0156 241
# MOD_0157 23
# MOD_0158 74
# MOD_0159 229
# MOD_0166 556
# MOD_0167 208
# MOD_0168 583
# MOD_0169 546
# MOD_0176 759
# MOD_0177 235
# MOD_0178 502
# MOD_0179 701
# MOD_0204 709
# MOD_0217 1524
# MOD_Month_0073 1740
# MOD_Month_0075 2045
# MOD_Month_0156 401
# MOD_Month_0157 34
# MOD_Month_0158 33
# MOD_Month_0159 269
# MOD_Month_0166 735
# MOD_Month_0167 187
# MOD_Month_0168 539
# MOD_Month_0169 792
# MOD_Month_0176 884
# MOD_Month_0177 354
# MOD_Month_0178 741
# MOD_Month_0179 940
# MOD_Month_0204 192
# MOD_Month_0217 2120
# MOD_Year_0073 1911
# MOD_Year_0075 2145
# MOD_Year_0156 278
# MOD_Year_0157 7
# MOD_Year_0158 35
# MOD_Year_0159 207
# MOD_Year_0166 701
# MOD_Year_0167 71
# MOD_Year_0168 496
# MOD_Year_0169 860
# MOD_Year_0176 717
# MOD_Year_0177 154
# MOD_Year_0178 475
# MOD_Year_0179 779
# MOD_Year_0204 95
# MOD_Year_0217 1786
#
#
# Dates With Mod 7, Mod 30, Mod 365, / 365
# XGBoost, 300 runs => 0.64472 (But get the max around run 100, at 0.646130)
#
#
# Feature Importances
# VAR_0073 1990
# VAR_0075 1992
# VAR_0156 312
# VAR_0157 16
# VAR_0158 30
# VAR_0159 186
# VAR_0166 754
# VAR_0167 116
# VAR_0168 608
# VAR_0169 1251
# VAR_0176 998
# VAR_0177 630
# VAR_0178 537
# VAR_0179 855
# VAR_0204 340
# VAR_0217 1782
# MOD_0073 1676
# MOD_0075 1340
# MOD_0156 248
# MOD_0157 28
# MOD_0158 65
# MOD_0159 227
# MOD_0166 441
# MOD_0167 124
# MOD_0168 524
# MOD_0169 521
# MOD_0176 600
# MOD_0177 311
# MOD_0178 458
# MOD_0179 670
# MOD_0204 587
# MOD_0217 1364
# MOD_Month_0073 1888
# MOD_Month_0075 1932
# MOD_Month_0156 393
# MOD_Month_0157 35
# MOD_Month_0158 44
# MOD_Month_0159 384
# MOD_Month_0166 671
# MOD_Month_0167 148
# MOD_Month_0168 632
# MOD_Month_0169 704
# MOD_Month_0176 717
# MOD_Month_0177 289
# MOD_Month_0178 564
# MOD_Month_0179 769
# MOD_Month_0204 144
# MOD_Month_0217 1963
# MOD_Year_0073 1717
# MOD_Year_0075 1710
# MOD_Year_0156 236
# MOD_Year_0157 5
# MOD_Year_0158 27
# MOD_Year_0159 231
# MOD_Year_0166 578
# MOD_Year_0167 97
# MOD_Year_0168 419
# MOD_Year_0169 654
# MOD_Year_0176 689
# MOD_Year_0177 173
# MOD_Year_0178 383
# MOD_Year_0179 809
# MOD_Year_0204 73
# MOD_Year_0217 1562
# Round_Year_0073 338
# Round_Year_0075 450
# Round_Year_0156 48
# Round_Year_0157 0
# Round_Year_0158 2
# Round_Year_0159 56
# Round_Year_0166 108
# Round_Year_0167 27
# Round_Year_0168 114
# Round_Year_0169 234
# Round_Year_0176 149
# Round_Year_0177 50
# Round_Year_0178 174
# Round_Year_0179 303
# Round_Year_0204 0
# Round_Year_0217 369
