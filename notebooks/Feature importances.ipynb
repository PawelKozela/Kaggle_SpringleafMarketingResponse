# %%
features_data = pickle.load(open(os.path.join(DATA_DIR, 'raw_feature_types.pickle')))

# %%
features_data
# Out:
# {'VAR_1277': ('Int', 'Score', [98, 97, 99], -1, None, 35L),
#  'VAR_0662': ('Int', 'Unknown', [], -1, 'Standard', 8L),
#  'VAR_0663': ('Int', 'Score', [98, 99], -1, None, 9L),
#  'VAR_0660': ('Int', 'Unknown', [], -1, 'Standard', 20719L),
#  'VAR_0661': ('Int', 'Unknown', [], -1, 'Standard', 363L),
#  'VAR_0666': ('Int', 'Unknown', [], -1, 'Standard', 9L),
#  'VAR_0667': ('Int', 'Unknown', [], -1, 'Standard', 7L),
#  'VAR_0664': ('Int', 'Unknown', [], -1, 'Standard', 7L),
#  'VAR_0665': ('Int', 'Unknown', [], -1, 'Standard', 7L),
#  'VAR_1274': ('Int', 'Score', [98, 99], -1, None, 56L),
#  'VAR_0668': ('Int', 'Unknown', [], -1, 'Standard', 7L),
#  'VAR_0669': ('Int', 'Unknown', [], -1, 'Standard', 3681L),
#  'VAR_0460': ('Float', 'Score', [], -1, None, 6L),
#  'VAR_0461': ('Float', 'Score', [], -1, None, 13L),
#  'VAR_0462': ('Float', 'Score', [], -1, None, 11L),
#  'VAR_0463': ('Float', 'Score', [], -1, None, 3L),
#  'VAR_0464': ('Float', 'Score', [], -1, None, 6L),
# ...
